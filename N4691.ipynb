# %%
import usb.core
import usb.util
from pathlib import Path

# Agilent / Keysight USB-ECal module (adjust if yours differs)
VID, PID = 0x0957, 0x0001

# Device-specific control requests (from the Facedancer emulator)
REQ_SET_PTR   = 0x02          # vendor OUT: set EEPROM read pointer
REQ_FINISH    = 0x04          # vendor OUT: optional “done”
BMRT_VENDOR_OUT = 0x40        # 0b01_00_0000  (Host→Dev | Vendor | Device)

BLOCK         = 0x20          # 32 bytes per read
EEPROM_BYTES  = 0x400         # 1 KiB total

TIMEOUT = 10                 # Timeout in ms

# %%
def find_ecal():
    """Locate the first matching USB device and claim its interface."""
    dev = usb.core.find(idVendor=VID, idProduct=PID)
    if dev is None:
        raise RuntimeError("ECal module not found (check VID/PID or driver).")

    # Detach any kernel driver (Linux/macOS) so libusb can talk to it
    # if dev.is_kernel_driver_active(0):
        # dev.detach_kernel_driver(0)

    dev.set_configuration()
    return dev


def get_bulk_in_ep(dev):
    """Return endpoint object for bulk-IN endpoint 1 (0x81)."""
    cfg  = dev.get_active_configuration()
    intf = cfg[(0, 0)]
    ep   = usb.util.find_descriptor(
        intf,
        # We want endpoint 1 with IN direction
        custom_match=lambda e: usb.util.endpoint_direction(e.bEndpointAddress)
                               == usb.util.ENDPOINT_IN
                               and (e.bEndpointAddress & 0x0F) == 1
    )
    if ep is None:
        raise RuntimeError("Bulk-IN endpoint 1 not found.")
    return ep


def set_pointer(dev, startAddress, addr):
    """Move internal read pointer to <addr>."""
    wValue = startAddress + EEPROM_BYTES - addr       # emulator logic: addr = 0x400 – wValue
    print("Requesting address: " + str(wValue))
    dev.ctrl_transfer(
        BMRT_VENDOR_OUT, REQ_SET_PTR,
        wValue=wValue, wIndex=0, data_or_wLength=None, timeout=TIMEOUT
    )

# %%
def dump_eeprom(startAddress, out_file: Path = Path("ecal_eeprom.bin")) -> Path:
    dev = find_ecal()
    ep  = get_bulk_in_ep(dev)

    data = bytearray()

    for offset in range(0, EEPROM_BYTES, BLOCK):
        set_pointer(dev, startAddress, offset)
        data.extend(ep.read(BLOCK, timeout=10))

    # Optional “we’re done” request (ignored by some modules)
    try:
        dev.ctrl_transfer(BMRT_VENDOR_OUT, REQ_FINISH, 0, 0, None, 10)
    except usb.core.USBError:
        pass

    out_file.write_bytes(data)
    print(f"Wrote {len(data)} bytes -> {out_file.resolve()}")
    return out_file

# %%
bin_path = dump_eeprom(0, Path("ecal_eeprom_testB_1.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x0400, Path("ecal_eeprom_testB_2.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x0800, Path("ecal_eeprom_testB_3.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x0c00, Path("ecal_eeprom_testB_4.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x1000, Path("ecal_eeprom_testB_5.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x1400, Path("ecal_eeprom_testB_6.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x1800, Path("ecal_eeprom_testB_7.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x1c00, Path("ecal_eeprom_testB_8.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))

bin_path = dump_eeprom(0x2000, Path("ecal_eeprom_testB_9.bin"))
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))


# Quick hex preview (first 64 bytes)
first = bin_path.read_bytes()[:64]
print(first.hex(" ", 1))
# Out:
# Requesting address: 1024
# Requesting address: 992
# Requesting address: 960
# Requesting address: 928
# Requesting address: 896
# Requesting address: 864
# Requesting address: 832
# Requesting address: 800
# Requesting address: 768
# Requesting address: 736
# Requesting address: 704
# Requesting address: 672
# Requesting address: 640
# Requesting address: 608
# Requesting address: 576
# Requesting address: 544
# Requesting address: 512
# Requesting address: 480
# Requesting address: 448
# Requesting address: 416
# Requesting address: 384
# Requesting address: 352
# Requesting address: 320
# Requesting address: 288
# Requesting address: 256
# Requesting address: 224
# Requesting address: 192
# Requesting address: 160
# Requesting address: 128
# Requesting address: 96
# Requesting address: 64
# Requesting address: 32
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_1.bin
# 48 50 38 35 30 36 30 43 20 45 43 41 4c 00 ff ff ff ff ff ff 64 00 4e 6f 76 20 32 38 20 31 39 39 34 00 64 00 ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff 02 00 ff ff ff ff ff ff ff ff
# Requesting address: 2048
# Requesting address: 2016
# Requesting address: 1984
# Requesting address: 1952
# Requesting address: 1920
# Requesting address: 1888
# Requesting address: 1856
# Requesting address: 1824
# Requesting address: 1792
# Requesting address: 1760
# Requesting address: 1728
# Requesting address: 1696
# Requesting address: 1664
# Requesting address: 1632
# Requesting address: 1600
# Requesting address: 1568
# Requesting address: 1536
# Requesting address: 1504
# Requesting address: 1472
# Requesting address: 1440
# Requesting address: 1408
# Requesting address: 1376
# Requesting address: 1344
# Requesting address: 1312
# Requesting address: 1280
# Requesting address: 1248
# Requesting address: 1216
# Requesting address: 1184
# Requesting address: 1152
# Requesting address: 1120
# Requesting address: 1088
# Requesting address: 1056
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_2.bin
# 00 00 00 00 2a 75 95 41 00 00 00 00 84 d7 97 41 00 00 00 00 a3 e1 a1 41 00 00 00 00 84 d7 a7 41 48 50 38 35 30 36 30 43 20 45 43 41 4c 00 ff ff ff ff ff ff 64 00 4e 6f 76 20 32 38 20 31 39 39
# Requesting address: 3072
# Requesting address: 3040
# Requesting address: 3008
# Requesting address: 2976
# Requesting address: 2944
# Requesting address: 2912
# Requesting address: 2880
# Requesting address: 2848
# Requesting address: 2816
# Requesting address: 2784
# Requesting address: 2752
# Requesting address: 2720
# Requesting address: 2688
# Requesting address: 2656
# Requesting address: 2624
# Requesting address: 2592
# Requesting address: 2560
# Requesting address: 2528
# Requesting address: 2496
# Requesting address: 2464
# Requesting address: 2432
# Requesting address: 2400
# Requesting address: 2368
# Requesting address: 2336
# Requesting address: 2304
# Requesting address: 2272
# Requesting address: 2240
# Requesting address: 2208
# Requesting address: 2176
# Requesting address: 2144
# Requesting address: 2112
# Requesting address: 2080
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_3.bin
# 00 00 00 00 84 d7 87 41 00 00 00 00 38 9c 8c 41 00 00 00 00 76 b0 90 41 00 00 00 00 d0 12 93 41 00 00 00 00 2a 75 95 41 00 00 00 00 84 d7 97 41 00 00 00 00 a3 e1 a1 41 00 00 00 00 84 d7 a7 41
# Requesting address: 4096
# Requesting address: 4064
# Requesting address: 4032
# Requesting address: 4000
# Requesting address: 3968
# Requesting address: 3936
# Requesting address: 3904
# Requesting address: 3872
# Requesting address: 3840
# Requesting address: 3808
# Requesting address: 3776
# Requesting address: 3744
# Requesting address: 3712
# Requesting address: 3680
# Requesting address: 3648
# Requesting address: 3616
# Requesting address: 3584
# Requesting address: 3552
# Requesting address: 3520
# Requesting address: 3488
# Requesting address: 3456
# Requesting address: 3424
# Requesting address: 3392
# Requesting address: 3360
# Requesting address: 3328
# Requesting address: 3296
# Requesting address: 3264
# Requesting address: 3232
# Requesting address: 3200
# Requesting address: 3168
# Requesting address: 3136
# Requesting address: 3104
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_4.bin
# 48 50 38 35 30 36 30 43 20 45 43 41 4c 00 ff ff ff ff ff ff 64 00 4e 6f 76 20 32 38 20 31 39 39 34 00 64 00 ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff ff 02 00 ff ff ff ff ff ff ff ff
# Requesting address: 5120
# Requesting address: 5088
# Requesting address: 5056
# Requesting address: 5024
# Requesting address: 4992
# Requesting address: 4960
# Requesting address: 4928
# Requesting address: 4896
# Requesting address: 4864
# Requesting address: 4832
# Requesting address: 4800
# Requesting address: 4768
# Requesting address: 4736
# Requesting address: 4704
# Requesting address: 4672
# Requesting address: 4640
# Requesting address: 4608
# Requesting address: 4576
# Requesting address: 4544
# Requesting address: 4512
# Requesting address: 4480
# Requesting address: 4448
# Requesting address: 4416
# Requesting address: 4384
# Requesting address: 4352
# Requesting address: 4320
# Requesting address: 4288
# Requesting address: 4256
# Requesting address: 4224
# Requesting address: 4192
# Requesting address: 4160
# Requesting address: 4128
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_5.bin
# 00 00 00 00 2a 75 95 41 00 00 00 00 84 d7 97 41 00 00 00 00 a3 e1 a1 41 00 00 00 00 84 d7 a7 41 00 00 00 00 65 cd ad 41 00 00 00 00 a3 e1 b1 41 00 00 00 80 93 dc b4 41 00 00 00 00 84 d7 b7 41
# Requesting address: 6144
# Requesting address: 6112
# Requesting address: 6080
# Requesting address: 6048
# Requesting address: 6016
# Requesting address: 5984
# Requesting address: 5952
# Requesting address: 5920
# Requesting address: 5888
# Requesting address: 5856
# Requesting address: 5824
# Requesting address: 5792
# Requesting address: 5760
# Requesting address: 5728
# Requesting address: 5696
# Requesting address: 5664
# Requesting address: 5632
# Requesting address: 5600
# Requesting address: 5568
# Requesting address: 5536
# Requesting address: 5504
# Requesting address: 5472
# Requesting address: 5440
# Requesting address: 5408
# Requesting address: 5376
# Requesting address: 5344
# Requesting address: 5312
# Requesting address: 5280
# Requesting address: 5248
# Requesting address: 5216
# Requesting address: 5184
# Requesting address: 5152
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_6.bin
# 00 00 00 08 33 07 f8 41 00 00 00 10 e2 36 f8 41 00 00 00 18 91 66 f8 41 00 00 00 20 40 96 f8 41 00 00 00 28 ef c5 f8 41 00 00 00 30 9e f5 f8 41 00 00 00 38 4d 25 f9 41 00 00 00 40 fc 54 f9 41
# Requesting address: 7168
# Requesting address: 7136
# Requesting address: 7104
# Requesting address: 7072
# Requesting address: 7040
# Requesting address: 7008
# Requesting address: 6976
# Requesting address: 6944
# Requesting address: 6912
# Requesting address: 6880
# Requesting address: 6848
# Requesting address: 6816
# Requesting address: 6784
# Requesting address: 6752
# Requesting address: 6720
# Requesting address: 6688
# Requesting address: 6656
# Requesting address: 6624
# Requesting address: 6592
# Requesting address: 6560
# Requesting address: 6528
# Requesting address: 6496
# Requesting address: 6464
# Requesting address: 6432
# Requesting address: 6400
# Requesting address: 6368
# Requesting address: 6336
# Requesting address: 6304
# Requesting address: 6272
# Requesting address: 6240
# Requesting address: 6208
# Requesting address: 6176
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_7.bin
# 00 00 00 84 5b ef 07 42 00 00 00 08 33 07 08 42 00 00 00 8c 0a 1f 08 42 00 00 00 10 e2 36 08 42 00 00 00 94 b9 4e 08 42 00 00 00 18 91 66 08 42 00 00 00 9c 68 7e 08 42 00 00 00 20 40 96 08 42
# Requesting address: 8192
# Requesting address: 8160
# Requesting address: 8128
# Requesting address: 8096
# Requesting address: 8064
# Requesting address: 8032
# Requesting address: 8000
# Requesting address: 7968
# Requesting address: 7936
# Requesting address: 7904
# Requesting address: 7872
# Requesting address: 7840
# Requesting address: 7808
# Requesting address: 7776
# Requesting address: 7744
# Requesting address: 7712
# Requesting address: 7680
# Requesting address: 7648
# Requesting address: 7616
# Requesting address: 7584
# Requesting address: 7552
# Requesting address: 7520
# Requesting address: 7488
# Requesting address: 7456
# Requesting address: 7424
# Requesting address: 7392
# Requesting address: 7360
# Requesting address: 7328
# Requesting address: 7296
# Requesting address: 7264
# Requesting address: 7232
# Requesting address: 7200
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_8.bin
# 00 00 00 c2 8e ed 11 42 00 00 00 84 7a f9 11 42 00 00 00 46 66 05 12 42 00 00 00 08 52 11 12 42 00 00 00 ca 3d 1d 12 42 00 00 00 8c 29 29 12 42 00 00 00 4e 15 35 12 42 00 00 00 10 01 41 12 42
# Requesting address: 9216
# Requesting address: 9184
# Requesting address: 9152
# Requesting address: 9120
# Requesting address: 9088
# Requesting address: 9056
# Requesting address: 9024
# Requesting address: 8992
# Requesting address: 8960
# Requesting address: 8928
# Requesting address: 8896
# Requesting address: 8864
# Requesting address: 8832
# Requesting address: 8800
# Requesting address: 8768
# Requesting address: 8736
# Requesting address: 8704
# Requesting address: 8672
# Requesting address: 8640
# Requesting address: 8608
# Requesting address: 8576
# Requesting address: 8544
# Requesting address: 8512
# Requesting address: 8480
# Requesting address: 8448
# Requesting address: 8416
# Requesting address: 8384
# Requesting address: 8352
# Requesting address: 8320
# Requesting address: 8288
# Requesting address: 8256
# Requesting address: 8224
# Wrote 1024 bytes -> C:\Users\hendo\OneDrive - rhconsulting.co.nz\Documents\Jupyter Notebooks\SNA5k\N4691-60004 eCal\ecal_eeprom_testB_9.bin
# 00 00 00 c2 6f e3 17 42 00 00 00 84 5b ef 17 42 00 00 00 46 47 fb 17 42 00 00 00 08 33 07 18 42 00 00 00 ca 1e 13 18 42 00 00 00 8c 0a 1f 18 42 00 00 00 4e f6 2a 18 42 00 00 00 10 e2 36 18 42
# 00 00 00 c2 6f e3 17 42 00 00 00 84 5b ef 17 42 00 00 00 46 47 fb 17 42 00 00 00 08 33 07 18 42 00 00 00 ca 1e 13 18 42 00 00 00 8c 0a 1f 18 42 00 00 00 4e f6 2a 18 42 00 00 00 10 e2 36 18 42

# %%
import usb.backend.libusb1 as lib1; 

print(lib1.get_backend())
# Out:
# <usb.backend.libusb1._LibUSB object at 0x000001605125A570>

# %%
import usb.core, usb.util, usb.backend.libusb1 as lib1, platform, sys, ctypes, shutil, os
backend = lib1.get_backend()
print(f"Python: {platform.python_version()}  ({platform.architecture()[0]})")
print(f"libusb backend: {backend or '❌ NOT FOUND'}")

# List every Agilent/Keysight USB device PyUSB can see
for d in usb.core.find(find_all=True, idVendor=0x0957):
    try:
        # string descriptors are optional; ignore failures
        mfg  = usb.util.get_string(d, d.iManufacturer)
        prod = usb.util.get_string(d, d.iProduct)
    except Exception:
        mfg = prod = "?"
    print(f"Found 0x0957:0x{d.idProduct:04x}  {mfg} – {prod}")
# Out:
# Python: 3.12.6  (64bit)
# libusb backend: <usb.backend.libusb1._LibUSB object at 0x0000020F46866E10>
# Found 0x0957:0x0107  ? – ?
# Found 0x0957:0x0001  Agilent Technologies – USB ECal Module
